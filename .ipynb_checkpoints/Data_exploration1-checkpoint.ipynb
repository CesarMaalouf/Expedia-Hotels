# %%
import numpy as np
import pandas as pd

# %%
with open('datapath.txt') as f:
    datapath=f.readlines()[0].rstrip()

# %%
traindata=pd.read_csv(datapath+'train.csv', nrows=int(1e5))

# %%
traindata['hotel_cluster'].hist(bins=100)

# %%
traindata.columns
# Out:
# Index([u'date_time', u'site_name', u'posa_continent', u'user_location_country',
#        u'user_location_region', u'user_location_city',
#        u'orig_destination_distance', u'user_id', u'is_mobile', u'is_package',
#        u'channel', u'srch_ci', u'srch_co', u'srch_adults_cnt',
#        u'srch_children_cnt', u'srch_rm_cnt', u'srch_destination_id',
#        u'srch_destination_type_id', u'is_booking', u'cnt', u'hotel_continent',
#        u'hotel_country', u'hotel_market', u'hotel_cluster'],
#       dtype='object')

# %%
nuniques=lambda x: x.unique().shape[0]

# %%
traindata.apply(nuniques,axis=0)
# Out:
# date_time                    99840
# site_name                       38
# posa_continent                   5
# user_location_country          123
# user_location_region           510
# user_location_city            3751
# orig_destination_distance    43022
# user_id                       3478
# is_mobile                        2
# is_package                       2
# channel                         11
# srch_ci                       1030
# srch_co                       1035
# srch_adults_cnt                 10
# srch_children_cnt               10
# srch_rm_cnt                      9
# srch_destination_id           5296
# srch_destination_type_id         8
# is_booking                       2
# cnt                             30
# hotel_continent                  6
# hotel_country                  152
# hotel_market                  1531
# hotel_cluster                  100
# dtype: int64

# %%
traindata.orig_destination_distance.hist(bins=100)

# %%
(traindata.orig_destination_distance<50).sum()
# Out:
# 3356

# %%
traindata[(traindata.orig_destination_distance<50)]['hotel_cluster'].hist(bins=100)

# %%
float(traindata.shape[0]-traindata.orig_destination_distance.unique().shape[0])/traindata.shape[0]
# Out:
# 0.56978

# %%
grpdist=traindata.groupby('orig_destination_distance')

# %%
undiff=lambda x: x.shape[0]-nuniques(x)

# %%
def corrs(x):
    if x.shape[0]>1:
        return undiff(x)>0
    else:
        return False

# %%
def perfect(x):
    if x.shape[0]>1:
        return nuniques(x)==1
    else:
        return False

# %%
multiples=(grpdist['hotel_cluster'].apply(lambda x: x.shape[0]>1))

# %%
ones=(grpdist['hotel_cluster'].apply(nuniques)==1)

# %%
uniques=(grpdist['hotel_cluster'].apply(nuniques))

# %%
type(ones[multiples])
# Out:
# pandas.core.series.Series

# %%
(ones[multiples][(ones[multiples]==True)]).
# Out:
# (10626,)

# %%
grpdist['hotel_cluster'].apply

# %%
traindata.columns
# Out:
# Index([u'date_time', u'site_name', u'posa_continent', u'user_location_country',
#        u'user_location_region', u'user_location_city',
#        u'orig_destination_distance', u'user_id', u'is_mobile', u'is_package',
#        u'channel', u'srch_ci', u'srch_co', u'srch_adults_cnt',
#        u'srch_children_cnt', u'srch_rm_cnt', u'srch_destination_id',
#        u'srch_destination_type_id', u'is_booking', u'cnt', u'hotel_continent',
#        u'hotel_country', u'hotel_market', u'hotel_cluster'],
#       dtype='object')

# %%
grpdistcity=traindata.groupby(['user_location_city',u'orig_destination_distance','user_location_country',u'user_location_region'])

# %%
multiples=grpdistcity['hotel_cluster'].apply(lambda x: x.shape[0]>1)

# %%
uniques=grpdistcity['hotel_cluster'].apply(nuniques)

# %%
(uniques[multiples]!=1).sum()
# Out:
# 413

# %%
pd.DataFrame(uniques[multiples]).groupby('hotel_cluster')
# Out:
# Object `count` not found.

# %%
nxtgrp=pd.DataFrame(uniques[multiples]).groupby('hotel_cluster')

# %%
nxtgrp.size()
# Out:
# hotel_cluster
# 1    10650
# 2      401
# 3       12
# dtype: int64
